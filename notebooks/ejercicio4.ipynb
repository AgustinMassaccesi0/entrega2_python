# %%
import sys
sys.path.append('../src')
import mailvalido

# %%
email = input('Ingrese un email:').strip()

while not mailvalido.email_valido (email):
    print ('Email invalido, ingrese otro')
    email = input('Ingrese un email:').strip()

print('Email valido')
# Out:
# Email valido
